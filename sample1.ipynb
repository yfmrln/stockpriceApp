# %%
# !pip3 install yfinance
# Out:
# Requirement already satisfied: yfinance in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.2.0)
# Requirement already satisfied: pandas>=1.3.0 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: requests>=2.31 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: pytz>=2022.5 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (4.0.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (6.33.5)
# Requirement already satisfied: websockets>=13.0 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.31->yfinance) (2.6.3)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

# %matplotlib inline

# %%
aapl = yf.Ticker('AAPL')

# %%
days = 20
hist = aapl.history(period=f'{days}d')
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-02-06 00:00:00-05:00  276.860920  280.647386  276.671095  277.859985
# 2026-02-09 00:00:00-05:00  277.910004  278.200012  271.700012  274.619995
# 2026-02-10 00:00:00-05:00  274.890015  275.369995  272.940002  273.679993
# 2026-02-11 00:00:00-05:00  274.700012  280.179993  274.450012  275.500000
# 2026-02-12 00:00:00-05:00  275.589996  275.720001  260.179993  261.730011
# 2026-02-13 00:00:00-05:00  262.010010  262.230011  255.449997  255.779999
# 2026-02-17 00:00:00-05:00  258.049988  266.290009  255.539993  263.880005
# 2026-02-18 00:00:00-05:00  263.600006  266.820007  262.450012  264.350006
# 2026-02-19 00:00:00-05:00  262.600006  264.480011  260.049988  260.579987
# 2026-02-20 00:00:00-05:00  258.970001  264.750000  258.160004  264.579987
# 2026-02-23 00:00:00-05:00  263.489990  269.429993  263.380005  266.179993
# 2026-02-24 00:00:00-05:00  267.859985  274.890015  267.709991  272.140015
# 2026-02-25 00:00:00-05:00  271.779999  274.940002  271.049988  274.230011
# 2026-02-26 00:00:00-05:00  274.950012  276.109985  270.799988  272.950012
# 2026-02-27 00:00:00-05:00  272.809998  272.809998  262.890015  264.179993
# 2026-03-02 00:00:00-05:00  262.410004  266.529999  260.200012  264.720001
# 2026-03-03 00:00:00-05:00  263.480011  265.559998  260.130005  263.750000
# 2026-03-04 00:00:00-05:00  264.649994  266.149994  261.420013  262.519989
# 2026-03-05 00:00:00-05:00  260.790009  261.559998  257.250000  260.290009
# 2026-03-06 00:00:00-05:00  258.630005  258.769989  254.369995  257.459991
#
#                              Volume  Dividends  Stock Splits
# Date
# 2026-02-06 00:00:00-05:00  50453400       0.00           0.0
# 2026-02-09 00:00:00-05:00  44623400       0.26           0.0
# 2026-02-10 00:00:00-05:00  34376900       0.00           0.0
# 2026-02-11 00:00:00-05:00  51931300       0.00           0.0
# 2026-02-12 00:00:00-05:00  81077200       0.00           0.0
# 2026-02-13 00:00:00-05:00  56290700       0.00           0.0
# 2026-02-17 00:00:00-05:00  58469100       0.00           0.0
# 2026-02-18 00:00:00-05:00  34203300       0.00           0.0
# 2026-02-19 00:00:00-05:00  30845300       0.00           0.0
# 2026-02-20 00:00:00-05:00  42070500       0.00           0.0
# 2026-02-23 00:00:00-05:00  37308200       0.00           0.0
# 2026-02-24 00:00:00-05:00  47014600       0.00           0.0
# 2026-02-25 00:00:00-05:00  33714300       0.00           0.0
# 2026-02-26 00:00:00-05:00  32345100       0.00           0.0
# 2026-02-27 00:00:00-05:00  72366500       0.00           0.0
# 2026-03-02 00:00:00-05:00  41827900       0.00           0.0
# 2026-03-03 00:00:00-05:00  38568900       0.00           0.0
# 2026-03-04 00:00:00-05:00  39803100       0.00           0.0
# 2026-03-05 00:00:00-05:00  49658600       0.00           0.0
# 2026-03-06 00:00:00-05:00  41094000       0.00           0.0

# %%
hist.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
hist.reset_index()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2026-02-06 00:00:00-05:00  276.860920  280.647386  276.671095  277.859985
# 1  2026-02-09 00:00:00-05:00  277.910004  278.200012  271.700012  274.619995
# 2  2026-02-10 00:00:00-05:00  274.890015  275.369995  272.940002  273.679993
# 3  2026-02-11 00:00:00-05:00  274.700012  280.179993  274.450012  275.500000
# 4  2026-02-12 00:00:00-05:00  275.589996  275.720001  260.179993  261.730011
# 5  2026-02-13 00:00:00-05:00  262.010010  262.230011  255.449997  255.779999
# 6  2026-02-17 00:00:00-05:00  258.049988  266.290009  255.539993  263.880005
# 7  2026-02-18 00:00:00-05:00  263.600006  266.820007  262.450012  264.350006
# 8  2026-02-19 00:00:00-05:00  262.600006  264.480011  260.049988  260.579987
# 9  2026-02-20 00:00:00-05:00  258.970001  264.750000  258.160004  264.579987
# 10 2026-02-23 00:00:00-05:00  263.489990  269.429993  263.380005  266.179993
# 11 2026-02-24 00:00:00-05:00  267.859985  274.890015  267.709991  272.140015
# 12 2026-02-25 00:00:00-05:00  271.779999  274.940002  271.049988  274.230011
# 13 2026-02-26 00:00:00-05:00  274.950012  276.109985  270.799988  272.950012
# 14 2026-02-27 00:00:00-05:00  272.809998  272.809998  262.890015  264.179993
# 15 2026-03-02 00:00:00-05:00  262.410004  266.529999  260.200012  264.720001
# 16 2026-03-03 00:00:00-05:00  263.480011  265.559998  260.130005  263.750000
# 17 2026-03-04 00:00:00-05:00  264.649994  266.149994  261.420013  262.519989
# 18 2026-03-05 00:00:00-05:00  260.790009  261.559998  257.250000  260.290009
# 19 2026-03-06 00:00:00-05:00  258.630005  258.769989  254.369995  257.459991
#
#       Volume  Dividends  Stock Splits
# 0   50453400       0.00           0.0
# 1   44623400       0.26           0.0
# 2   34376900       0.00           0.0
# 3   51931300       0.00           0.0
# 4   81077200       0.00           0.0
# 5   56290700       0.00           0.0
# 6   58469100       0.00           0.0
# 7   34203300       0.00           0.0
# 8   30845300       0.00           0.0
# 9   42070500       0.00           0.0
# 10  37308200       0.00           0.0
# 11  47014600       0.00           0.0
# 12  33714300       0.00           0.0
# 13  32345100       0.00           0.0
# 14  72366500       0.00           0.0
# 15  41827900       0.00           0.0
# 16  38568900       0.00           0.0
# 17  39803100       0.00           0.0
# 18  49658600       0.00           0.0
# 19  41094000       0.00           0.0

# %%
hist_msft = yf.Ticker('MSFT').history(period=f'{days}d')
hist_msft.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-02-06 00:00:00-05:00  398.260987  400.875015  392.025220  400.226501
# 2026-02-09 00:00:00-05:00  403.928068  413.945213  399.957120  412.658142
# 2026-02-10 00:00:00-05:00  418.664403  422.715155  411.760179  412.328857
# 2026-02-11 00:00:00-05:00  415.232230  415.511591  400.096794  403.449127
# 2026-02-12 00:00:00-05:00  404.077704  405.274983  397.103632  400.924896
#
#                              Volume  Dividends  Stock Splits
# Date
# 2026-02-06 00:00:00-05:00  53515300        0.0           0.0
# 2026-02-09 00:00:00-05:00  45480500        0.0           0.0
# 2026-02-10 00:00:00-05:00  44857900        0.0           0.0
# 2026-02-11 00:00:00-05:00  42491000        0.0           0.0
# 2026-02-12 00:00:00-05:00  40802400        0.0           0.0

# %%
pd.concat([hist, hist_msft], axis=1).head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-02-06 00:00:00-05:00  276.860920  280.647386  276.671095  277.859985
# 2026-02-09 00:00:00-05:00  277.910004  278.200012  271.700012  274.619995
# 2026-02-10 00:00:00-05:00  274.890015  275.369995  272.940002  273.679993
# 2026-02-11 00:00:00-05:00  274.700012  280.179993  274.450012  275.500000
# 2026-02-12 00:00:00-05:00  275.589996  275.720001  260.179993  261.730011
#
#                              Volume  Dividends  Stock Splits        Open  \
# Date
# 2026-02-06 00:00:00-05:00  50453400       0.00           0.0  398.260987
# 2026-02-09 00:00:00-05:00  44623400       0.26           0.0  403.928068
# 2026-02-10 00:00:00-05:00  34376900       0.00           0.0  418.664403
# 2026-02-11 00:00:00-05:00  51931300       0.00           0.0  415.232230
# 2026-02-12 00:00:00-05:00  81077200       0.00           0.0  404.077704
#
#                                  High         Low       Close    Volume  \
# Date
# 2026-02-06 00:00:00-05:00  400.875015  392.025220  400.226501  53515300
# 2026-02-09 00:00:00-05:00  413.945213  399.957120  412.658142  45480500
# 2026-02-10 00:00:00-05:00  422.715155  411.760179  412.328857  44857900
# 2026-02-11 00:00:00-05:00  415.511591  400.096794  403.449127  42491000
# 2026-02-12 00:00:00-05:00  405.274983  397.103632  400.924896  40802400
#
#                            Dividends  Stock Splits
# Date
# 2026-02-06 00:00:00-05:00        0.0           0.0
# 2026-02-09 00:00:00-05:00        0.0           0.0
# 2026-02-10 00:00:00-05:00        0.0           0.0
# 2026-02-11 00:00:00-05:00        0.0           0.0
# 2026-02-12 00:00:00-05:00        0.0           0.0

# %%
hist.head(3)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-02-06 00:00:00-05:00  276.860920  280.647386  276.671095  277.859985
# 2026-02-09 00:00:00-05:00  277.910004  278.200012  271.700012  274.619995
# 2026-02-10 00:00:00-05:00  274.890015  275.369995  272.940002  273.679993
#
#                              Volume  Dividends  Stock Splits
# Date
# 2026-02-06 00:00:00-05:00  50453400       0.00           0.0
# 2026-02-09 00:00:00-05:00  44623400       0.26           0.0
# 2026-02-10 00:00:00-05:00  34376900       0.00           0.0

# %%
hist.index
# Out:
# DatetimeIndex(['2026-02-06 00:00:00-05:00', '2026-02-09 00:00:00-05:00',
#                '2026-02-10 00:00:00-05:00', '2026-02-11 00:00:00-05:00',
#                '2026-02-12 00:00:00-05:00', '2026-02-13 00:00:00-05:00',
#                '2026-02-17 00:00:00-05:00', '2026-02-18 00:00:00-05:00',
#                '2026-02-19 00:00:00-05:00', '2026-02-20 00:00:00-05:00',
#                '2026-02-23 00:00:00-05:00', '2026-02-24 00:00:00-05:00',
#                '2026-02-25 00:00:00-05:00', '2026-02-26 00:00:00-05:00',
#                '2026-02-27 00:00:00-05:00', '2026-03-02 00:00:00-05:00',
#                '2026-03-03 00:00:00-05:00', '2026-03-04 00:00:00-05:00',
#                '2026-03-05 00:00:00-05:00', '2026-03-06 00:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', freq=None)

# %%
hist = hist[['Close']]
hist.columns = ['apple']
hist.head()
# Out:
#                                 apple
# Date
# 2026-02-06 00:00:00-05:00  277.859985
# 2026-02-09 00:00:00-05:00  274.619995
# 2026-02-10 00:00:00-05:00  273.679993
# 2026-02-11 00:00:00-05:00  275.500000
# 2026-02-12 00:00:00-05:00  261.730011

# %%
hist = hist.T
hist
# Out:
# Date   2026-02-06 00:00:00-05:00  2026-02-09 00:00:00-05:00  \
# apple                 277.859985                 274.619995
#
# Date   2026-02-10 00:00:00-05:00  2026-02-11 00:00:00-05:00  \
# apple                 273.679993                      275.5
#
# Date   2026-02-12 00:00:00-05:00  2026-02-13 00:00:00-05:00  \
# apple                 261.730011                 255.779999
#
# Date   2026-02-17 00:00:00-05:00  2026-02-18 00:00:00-05:00  \
# apple                 263.880005                 264.350006
#
# Date   2026-02-19 00:00:00-05:00  2026-02-20 00:00:00-05:00  \
# apple                 260.579987                 264.579987
#
# Date   2026-02-23 00:00:00-05:00  2026-02-24 00:00:00-05:00  \
# apple                 266.179993                 272.140015
#
# Date   2026-02-25 00:00:00-05:00  2026-02-26 00:00:00-05:00  \
# apple                 274.230011                 272.950012
#
# Date   2026-02-27 00:00:00-05:00  2026-03-02 00:00:00-05:00  \
# apple                 264.179993                 264.720001
#
# Date   2026-03-03 00:00:00-05:00  2026-03-04 00:00:00-05:00  \
# apple                     263.75                 262.519989
#
# Date   2026-03-05 00:00:00-05:00  2026-03-06 00:00:00-05:00
# apple                 260.290009                 257.459991

# %%
hist.index.name = 'Name'

# %%
hist
# Out:
# Date   2026-02-06 00:00:00-05:00  2026-02-09 00:00:00-05:00  \
# Name
# apple                 277.859985                 274.619995
#
# Date   2026-02-10 00:00:00-05:00  2026-02-11 00:00:00-05:00  \
# Name
# apple                 273.679993                      275.5
#
# Date   2026-02-12 00:00:00-05:00  2026-02-13 00:00:00-05:00  \
# Name
# apple                 261.730011                 255.779999
#
# Date   2026-02-17 00:00:00-05:00  2026-02-18 00:00:00-05:00  \
# Name
# apple                 263.880005                 264.350006
#
# Date   2026-02-19 00:00:00-05:00  2026-02-20 00:00:00-05:00  \
# Name
# apple                 260.579987                 264.579987
#
# Date   2026-02-23 00:00:00-05:00  2026-02-24 00:00:00-05:00  \
# Name
# apple                 266.179993                 272.140015
#
# Date   2026-02-25 00:00:00-05:00  2026-02-26 00:00:00-05:00  \
# Name
# apple                 274.230011                 272.950012
#
# Date   2026-02-27 00:00:00-05:00  2026-03-02 00:00:00-05:00  \
# Name
# apple                 264.179993                 264.720001
#
# Date   2026-03-03 00:00:00-05:00  2026-03-04 00:00:00-05:00  \
# Name
# apple                     263.75                 262.519989
#
# Date   2026-03-05 00:00:00-05:00  2026-03-06 00:00:00-05:00
# Name
# apple                 260.290009                 257.459991

# %%
def get_data(days, tickers):
    df = pd.DataFrame()
    for company in tickers.keys():
    # company = 'facebook'
        tkr = yf.Ticker(tickers[company])
        hist = tkr.history(period=f'{days}d')
        hist.index = hist.index.strftime('%d %B %Y')
        hist = hist[['Close']]
        hist.columns = [company]
        hist = hist.T
        hist.index.name = 'Name'
        df = pd.concat([df, hist])
    return df

# %%
days = 20
tickers = {
    'apple': 'AAPL',
    'facebook': 'FB',
    'google': 'GOOGL',
    'microsoft': 'MSFT',
    'netflix': 'NFLX',
    'amazon': 'AMZN'
}

get_data(days, tickers)
# Out:
# Date       06 February 2026  09 February 2026  10 February 2026  \
# Name
# apple            277.859985        274.619995        273.679993
# facebook          42.419998         42.542000         42.540001
# google           322.859985        324.320007        318.579987
# microsoft        400.226501        412.658142        412.328857
# netflix           82.199997         81.470001         82.209999
# amazon           210.320007        208.720001        206.960007
#
# Date       11 February 2026  12 February 2026  13 February 2026  \
# Name
# apple            275.500000        261.730011        255.779999
# facebook          42.490002         42.283001         42.330002
# google           310.959991        309.000000        305.720001
# microsoft        403.449127        400.924896        400.406097
# netflix           79.620003         75.860001         76.870003
# amazon           204.080002        199.600006        198.789993
#
# Date       17 February 2026  18 February 2026  19 February 2026  \
# Name
# apple            263.880005        264.350006        260.579987
# facebook          42.360001         42.360001         42.313000
# google           302.019989        303.329987        302.850006
# microsoft        395.956238        398.690002        398.459991
# netflix           77.000000         77.989998         77.000000
# amazon           201.149994        204.789993        204.860001
#
# Date       20 February 2026  23 February 2026  24 February 2026  \
# Name
# apple            264.579987        266.179993        272.140015
# facebook          42.411999         42.369999         42.491001
# google           314.980011        311.489990        310.899994
# microsoft        397.230011        384.470001        389.000000
# netflix           78.669998         76.019997         78.040001
# amazon           210.110001        205.270004        208.559998
#
# Date       25 February 2026  26 February 2026  27 February 2026  \
# Name
# apple            274.230011        272.950012        264.179993
# facebook          42.681000         42.639999         42.615002
# google           312.899994        307.380005        311.760010
# microsoft        400.600006        401.720001        392.739990
# netflix           82.699997         84.589996         96.239998
# amazon           210.639999        207.919998        210.000000
#
# Date       02 March 2026  03 March 2026  04 March 2026  05 March 2026  \
# Name
# apple         264.720001     263.750000     262.519989     260.290009
# facebook       42.571999      42.519001      42.604000      42.571999
# google        306.519989     303.579987     303.130005     300.880005
# microsoft     398.549988     403.929993     405.200012     410.679993
# netflix        97.089996      97.699997      98.660004      99.169998
# amazon        208.389999     208.729996     216.820007     218.940002
#
# Date       06 March 2026
# Name
# apple         257.459991
# facebook       42.418999
# google        298.519989
# microsoft     408.959991
# netflix        99.019997
# amazon        213.210007

# %%
aapl = yf.Ticker('AAPL')

# %%
aapl.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple Vision Pro, Apple TV, Apple Watch, Beats products, and HomePod, as well as Apple branded and third-party accessories. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV, which offers exclusive original content and live sports; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers and resellers. The company was formerly known as Apple Computer, Inc. and changed its name to Apple Inc. in January 2007. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#  'fullTimeEmployees': 150000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Timothy D. Cook',
#    'age': 64,
#    'title': 'CEO & Director',
#    'yearBorn': 1961,
#    'fiscalYear': 2025,
#    'totalPay': 16759518,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Kevan  Parekh',
#    'age': 53,
#    'title': 'Senior VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2025,
#    'totalPay': 4034174,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Sabih  Khan',
#    'age': 58,
#    'title': 'Senior VP & Chief Operating Officer',
#    'yearBorn': 1967,
#    'fiscalYear': 2025,
#    'totalPay': 5021905,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': "Ms. Deirdre  O'Brien",
#    'age': 58,
#    'title': 'Senior Vice President of Retail & People',
#    'yearBorn': 1967,
#    'fiscalYear': 2025,
#    'totalPay': 5037867,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Katherine L. Adams',
#    'age': 61,
#    'title': 'Senior VP & Secretary',
#    'yearBorn': 1964,
#    'fiscalYear': 2025,
#    'totalPay': 5022482,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Ben  Borders',
#    'age': 44,
#    'title': 'Principal Accounting Officer',
#    'yearBorn': 1981,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Suhasini  Chandramouli',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Jennifer G. Newstead J.D.',
#    'age': 54,
#    'title': 'Senior VP & General Counsel',
#    'yearBorn': 1971,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Kristin Huguet Quayle',
#    'title': 'Vice President of Worldwide Communications',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Greg  Joswiak',
#    'title': 'Senior Vice President of Worldwide Marketing',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 2,
#  'boardRisk': 1,
#  'compensationRisk': 7,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 1,
#  'governanceEpochDate': 1772323200,
#  'compensationAsOfEpochDate': 1767139200,
#  'irWebsite': 'http://investor.apple.com/',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 260.29,
#  'open': 258.74,
#  'dayLow': 254.37,
#  'dayHigh': 258.76,
#  'regularMarketPreviousClose': 260.29,
#  'regularMarketOpen': 258.74,
#  'regularMarketDayLow': 254.37,
#  'regularMarketDayHigh': 258.76,
#  'dividendRate': 1.04,
#  'dividendYield': 0.4,
#  'exDividendDate': 1770595200,
#  'payoutRatio': 0.1304,
#  'fiveYearAvgDividendYield': 0.52,
#  'beta': 1.116,
#  'trailingPE': 32.58987,
#  'forwardPE': 27.716951,
#  'volume': 40628988,
#  'regularMarketVolume': 40628988,
#  'averageVolume': 48022439,
#  'averageVolume10days': 43370120,
#  'averageDailyVolume10Day': 43370120,
#  'bid': 256.93,
#  'ask': 271.51,
#  'bidSize': 2,
#  'askSize': 1,
#  'marketCap': 3784127807488,
#  'nonDilutedMarketCap': 3779806304400,
#  'fiftyTwoWeekLow': 169.21,
#  'fiftyTwoWeekHigh': 288.62,
#  'allTimeHigh': 288.62,
#  'allTimeLow': 0.049107,
#  'priceToSalesTrailing12Months': 8.686823,
#  'fiftyDayAverage': 264.2878,
#  'twoHundredDayAverage': 244.17625,
#  'trailingAnnualDividendRate': 1.03,
#  'trailingAnnualDividendYield': 0.0039571244,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 3803408236544,
#  'profitMargins': 0.27037,
#  'floatShares': 14656182062,
#  'sharesOutstanding': 14681140000,
#  'sharesShort': 133373267,
#  'sharesShortPriorMonth': 113576032,
#  'sharesShortPreviousMonthDate': 1768435200,
#  'dateShortInterest': 1770940800,
#  'sharesPercentSharesOut': 0.0091,
#  'heldPercentInsiders': 0.01637,
#  'heldPercentInstitutions': 0.65200996,
#  'shortRatio': 2.32,
#  'shortPercentOfFloat': 0.0091,
#  'impliedSharesOutstanding': 14697926000,
#  'bookValue': 5.998,
#  'priceToBook': 42.924305,
#  'lastFiscalYearEnd': 1758931200,
#  'nextFiscalYearEnd': 1790467200,
#  'mostRecentQuarter': 1766793600,
#  'earningsQuarterlyGrowth': 0.159,
#  'netIncomeToCommon': 117776998400,
#  'trailingEps': 7.9,
#  'forwardEps': 9.2889,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 1598832000,
#  'enterpriseToRevenue': 8.731,
#  'enterpriseToEbitda': 24.875,
#  '52WeekChange': 0.13179183,
#  'SandP52WeekChange': 0.20045388,
#  'lastDividendValue': 0.26,
#  'lastDividendDate': 1770595200,
#  'quoteType': 'EQUITY',
#  'currentPrice': 257.46,
#  'targetHighPrice': 350.0,
#  'targetLowPrice': 205.0,
#  'targetMeanPrice': 292.14624,
#  'targetMedianPrice': 300.0,
#  'recommendationMean': 1.91667,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 40,
#  'totalCash': 66907000832,
#  'totalCashPerShare': 4.557,
#  'ebitda': 152901992448,
#  'totalDebt': 90509000704,
#  'quickRatio': 0.845,
#  'currentRatio': 0.974,
#  'totalRevenue': 435617005568,
#  'debtToEquity': 102.63,
#  'revenuePerShare': 29.305,
#  'returnOnAssets': 0.24377,
#  'returnOnEquity': 1.5202099,
#  'grossProfits': 206157004800,
#  'freeCashflow': 106312753152,
#  'operatingCashflow': 135471996928,
#  'earningsGrowth': 0.183,
#  'revenueGrowth': 0.157,
#  'grossMargins': 0.47325,
#  'ebitdaMargins': 0.35099998,
#  'operatingMargins': 0.35374,
#  'financialCurrency': 'USD',
#  'symbol': 'AAPL',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'postMarketChangePercent': -0.31461105,
#  'postMarketPrice': 256.65,
#  'postMarketChange': -0.80999756,
#  'regularMarketChange': -2.83002,
#  'regularMarketDayRange': '254.37 - 258.76',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 48022439,
#  'fiftyTwoWeekLowChange': 88.249985,
#  'fiftyTwoWeekLowChangePercent': 0.5215412,
#  'fiftyTwoWeekRange': '169.21 - 288.62',
#  'fiftyTwoWeekHighChange': -31.160004,
#  'fiftyTwoWeekHighChangePercent': -0.10796204,
#  'fiftyTwoWeekChangePercent': 13.179183,
#  'dividendDate': 1770854400,
#  'earningsTimestamp': 1769720400,
#  'earningsTimestampStart': 1777579200,
#  'earningsTimestampEnd': 1777579200,
#  'earningsCallTimestampStart': 1769724000,
#  'earningsCallTimestampEnd': 1769724000,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': 7.9,
#  'epsForward': 9.2889,
#  'epsCurrentYear': 8.49805,
#  'priceEpsCurrentYear': 30.296362,
#  'fiftyDayAverageChange': -6.82782,
#  'fiftyDayAverageChangePercent': -0.02583479,
#  'twoHundredDayAverageChange': 13.283737,
#  'twoHundredDayAverageChangePercent': 0.054402247,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '1.9 - Buy',
#  'cryptoTradeable': False,
#  'corporateActions': [],
#  'postMarketTime': 1772845199,
#  'regularMarketTime': 1772830802,
#  'regularMarketChangePercent': -1.08726,
#  'regularMarketPrice': 257.46,
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_24937',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'gmtOffSetMilliseconds': -18000000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 345479400000,
#  'marketState': 'CLOSED',
#  'displayName': 'Apple',
#  'trailingPegRatio': 2.3044}

# %%
aapl.actions.head()
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-05-11 00:00:00-04:00   0.000536           0.0
# 1987-06-16 00:00:00-04:00   0.000000           2.0
# 1987-08-10 00:00:00-04:00   0.000536           0.0
# 1987-11-17 00:00:00-05:00   0.000714           0.0
# 1988-02-12 00:00:00-05:00   0.000714           0.0

# %%
aapl.dividends.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
aapl.actions['Stock Splits'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# !pip3 install altair
# Out:
# Requirement already satisfied: altair in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (6.0.0)
# Requirement already satisfied: jinja2 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from altair) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from altair) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from altair) (2.16.0)
# Requirement already satisfied: packaging in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from altair) (26.0)
# Requirement already satisfied: typing-extensions>=4.12.0 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from altair) (4.15.0)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jsonschema>=3.0->altair) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jsonschema>=3.0->altair) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jsonschema>=3.0->altair) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jsonschema>=3.0->altair) (0.30.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\81806\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jinja2->altair) (3.0.3)

# %%
import altair as alt

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
companies = ['apple', 'facebook']
data = df.loc[companies]
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 companies = ['apple', 'facebook']
# ----> 2 data = df.loc[companies]
#       3 data
#
# NameError: name 'df' is not defined

# %%
data.sort_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 data.sort_index()
#
# NameError: name 'data' is not defined

# %%
data = data.T.reset_index()
data.head()

# %%
data = pd.melt(data, id_vars=['Date']).rename(
    columns={'value': 'Stock Prices(USD)'}
)
data

# %%
ymin, ymax = 250, 300

chart = (
    alt.Chart(data)
    .mark_line(opacity=0.8, clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Stock Prices(USD):Q", stack=None, scale=alt.Scale(domain=[ymin, ymax])),
        color='Name:N'
    )
)
